# %%
#Ejemplo 4.1 
import numpy as np
def vectorfield(w, t, p):
    """
    Definimos las ecuaciones diferenciales para el sistema de doble masa-resorte.
    Arguments:
        w : Vector del estado de las variables 
                  w = [x1,y1,x2,y2]
        t :  Tiempo
        p :  Vector de los parametros:
                  p = [m1,m2,k1,k2,L1,L2,b1,b2]
    """
    x1, y1, x2, y2 = w
    #Agregamos los coeficientes no lineales al vector de parámetros
    m1, m2, k1, k2, L1, L2, b1, b2, c1, c2, F1, F2, w1, w2 = p

    #Creamos f = (x1',y1',x2',y2')
    #Como vamos a usar una fuerza no lineal, debemos modificar la ecuación que trabajamos en la Actividad pasada
    f = [y1,
         (-b1 * y1 - k1 * (x1 - L1) + c1 * (x1 - L1) ** 3.0 - k2 * (x1 - x2 - L2) + c2 * (x1 - x2- L2) ** 3.0 + F1 * np.cos(w1 * t)) / m1,
         y2,
         (-b2 * y2 - k2 * (x2 - x1 - L2) + c2 * (x2 - x1 - L2) ** 3.0 + F2 * np.cos(w2 * t)) / m2]
    return f

# %%
#Usamos la funcion ODEINT para resolver las ecuaciones diferenciales definidas por el vector
from scipy.integrate import odeint
import numpy as np

#Valor de los parametros
# Masas:
m1 = 1.0
m2 = 1.0
# Constante del resorte
k1 = 2.0/5.0
k2 = 1.0
# Longitudes naturales
L1 = 0
L2 = 0
# Coeficientes de fricción
b1 = 1.0/10.0
b2 = 1.0/5.0

#Parametros de coeficientes no lineales
c1=1.0/6.0
c2=1.0/10.0

#Parametros de Fuerza
F1=1.0/3.0
F2=1.0/5.0

#Parametros de la frecuencia de la Fuerza
w1=1.0
w2=3.0/5.0

# Condiciones iniciales
# x1 and x2 son las pocisiones iniciales(contando la longitud de L), y y1 y y2 son las velocidades
x1 = 0.7
y1 = 0.0
x2 = 0.1
y2 = 0.0

# Parametros de la ED
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 170.0
numpoints = 2250

#Creamos los valores del tiempo, entre mas puntos damos, mejores se veran las graficas.
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Ponemos a las variables en un vector.
#Agregamos los coeficientes no lineales
p = [m1, m2, k1, k2, L1, L2, b1, b2, c1, c2, F1, F2, w1, w2 ]
w0 = [x1, y1, x2, y2]

# Llamamos a la funcion para resolver la ED
wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('ejemplo4.1.dat', 'w') as f:
    # Imprimimos en el documento la solución
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], w1[2], w1[3], file=f)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, ylabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
#Estas bibliotecas van a crearme una imagen en otra pestaña, para hacer que la imagen aparezca dentro del mismo documento que estamos programando agregamos
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('ejemplo4.1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
grid(True)
#hold(True)
lw = 1.5

plot(x1, xy, 'tab:pink', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('$x_1$ contra $x_2$')
savefig('ejemplo4.1_pt1.png', dpi=100)

# %%
#Siguiente gráfica
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('ejemplo4.1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)
lw = 1.5

plot(x2, y2, 'tab:cyan', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Gráfica $x_2$')
savefig('Ejemplo4.1_pt2.png', dpi=100)

# %%
#Siguiente gráfica
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('ejemplo4.1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)
lw = 1.5

plot( t, x1, 'tab:pink', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Gráfica $x_2$ contra tiempo')
savefig('Ejemplo4.1_pt3.png', dpi=100)

# %%
#Para crear las gráficas después de que se estabiliza, necesitamos saltar al tiempo en donde ocurre eso omitiendo todos los renglones 
#hasta que ocurre.
#Usamos la funcion ODEINT para resolver las ecuaciones diferenciales definidas por el vector

from scipy.integrate import odeint
import numpy as np

#Valor de los parametros
# Masas:
m1 = 1.0
m2 = 1.0
# Constante del resorte
k1 = 2.0/5.0
k2 = 1.0
# Longitudes naturales
L1 = 0
L2 = 0
# Coeficientes de fricción
b1 = 1.0/10.0
b2 = 1.0/5.0

#Parametros de coeficientes no lineales
c1=1.0/6.0
c2=1.0/10.0

#Parametros de Fuerza
F1=1.0/3.0
F2=1.0/5.0

#Parametros de la frecuencia de la Fuerza
w1=1.0
w2=3.0/5.0

# Condiciones iniciales
# x1 and x2 son las pocisiones iniciales(contando la longitud de L), y y1 y y2 son las velocidades
x1 = 0.7
y1 = 0.0
x2 = 0.1
y2 = 0.0

# Parametros de la ED
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 3000.0
numpoints = 2250

#Creamos los valores del tiempo, entre mas puntos damos, mejores se veran las graficas.
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Ponemos a las variables en un vector.
#Agregamos los coeficientes no lineales
p = [m1, m2, k1, k2, L1, L2, b1, b2, c1, c2, F1, F2, w1, w2 ]
w0 = [x1, y1, x2, y2]

# Llamamos a la funcion para resolver la ED
wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('ejemplo4.11.dat', 'w') as f:
    # Imprimimos en el documento la solución
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], w1[2], w1[3], file=f)

# %%
#Cuando la gráfica se estabiliza es después del 1000, que se acaba en la línea 752, entonces escribimos skiprows:
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('ejemplo4.11.dat', unpack=True, skiprows=752)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)
lw = 1.5

plot( x1, xy, 'tab:cyan', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Gráfica $x_1$ estabilizado')
savefig('Ejemplo4.1_pt4.png', dpi=100)

# %%
#Siguiente gráfica

# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('ejemplo4.11.dat', unpack=True, skiprows=752)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)
lw = 1.5

plot( x2, y2, 'tab:pink', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Gráfica $x_1$ estabilizado')
savefig('Ejemplo4.1_pt5.png', dpi=100)

# %%
#Siguiente gráfica

# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('ejemplo4.1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)
lw = 1.5

plot( t, x1, 'm', linewidth=lw)
plot( t, x2, 'b', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Gráfica $x_1$ y $x_2$')
savefig('Ejemplo4.1_pt6.png', dpi=100)

# %%
from scipy.integrate import odeint
import numpy as np

#Valor de los parametros
# Masas:
m1 = 1.0
m2 = 1.0
# Constante del resorte
k1 = 2.0/5.0
k2 = 1.0
# Longitudes naturales
L1 = 0
L2 = 0
# Coeficientes de fricción
b1 = 1.0/10.0
b2 = 1.0/5.0

#Parametros de coeficientes no lineales
c1=1.0/6.0
c2=1.0/10.0

#Parametros de Fuerza
F1=1.0/3.0
F2=1.0/5.0

#Parametros de la frecuencia de la Fuerza
w1=1.0
w2=3.0/5.0

# Condiciones iniciales
# x1 and x2 son las pocisiones iniciales(contando la longitud de L), y y1 y y2 son las velocidades
x1 = 0.7
y1 = 0.0
x2 = 0.1
y2 = 0.0

# Parametros de la ED
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 2000.0
numpoints = 2250

#Creamos los valores del tiempo, entre mas puntos damos, mejores se veran las graficas.
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Ponemos a las variables en un vector.
#Agregamos los coeficientes no lineales
p = [m1, m2, k1, k2, L1, L2, b1, b2, c1, c2, F1, F2, w1, w2 ]
w0 = [x1, y1, x2, y2]

# Llamamos a la funcion para resolver la ED
wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('ejemplo4.12.dat', 'w') as f:
    # Imprimimos en el documento la solución
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], w1[2], w1[3], file=f)

# %%
#Siguiente gráfica

# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('ejemplo4.12.dat', unpack=True, skiprows=500)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)
lw = 1.0

plot( x1, x2, 'm', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Gráfica $x_1$ y $x_2$')
savefig('Ejemplo4.1_pt7.png', dpi=100)
